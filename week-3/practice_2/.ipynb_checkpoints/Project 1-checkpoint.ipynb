# %%
import tkinter as tk
from tkinter import messagebox as msgbox
import GIG-Logistics.csv

def verify_employee():
    name = name_entry.get().lower()
    department = dept_entry.get().lower()

    found = False
    dept_members = []

 with open("GIG-logistics.csv", "r"):
as file:
    reader = csv.DictReader(file)

    for row in reader:
    if row["Department"].lower() == dept:
        
    members.append(row["Name"])
        
    if row["Name"].lower() ==
   name and row ["Department"].lower() == dept:
        
        found = True

      result_box.delete("1.0", tk.END)
  if found:
      result_box.insert("1.0", tk.END,
    "Welcome" + name.title() + "\n\n")
      result_box.insert(tk.END,
    "Department Members:\n")

      for person in members:
          if person.lower() !=name:
              result.insert(tk.END, person + "\n")
              
else:
  result.insert(tk.END, "Employee does not exist")

# GUI
window = tk.Tk()
root.title("Employee Verification")

#Name Input
tk.Label(window, text="Name").pack()
name_entry = tk.Entry(window)
name_entry.pack()

#Department Input
tk.Label(window, text="Department").pack()
dept_entry = tk.Entry(window)
dept_entry.pack()

# Button
tk.Button(window, text="Check",
command=check_employee).pack()

#Result display
result_box = tk.Text(window, height=8,
width=35)
result.pack()

window.mainloop()
# Out:
#   File <string>:12
#     with open("GIG-logistics.csv", "r"):
#                                         ^
# IndentationError: unindent does not match any outer indentation level
